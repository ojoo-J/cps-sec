# %% [markdown]
# ## 1. 데이터불러오기

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
import re
from tqdm import tqdm
from gensim.models import Word2Vec
from sklearn.cluster import KMeans
import os
from konlpy.tag import Hannanum, Kkma, Komoran, Okt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### 의안데이터

# %%
BillDf_20 = pd.read_csv('/content/drive/My Drive/cuai-conf/20th.csv', parse_dates=['제안일자','의결일자'])
BillDf_21 = pd.read_csv("/content/drive/My Drive/cuai-conf/21대 국회 의안정보 new.csv", parse_dates=['제안일자','의결일자'], encoding='utf-8-sig') #200824업데이트
BillDf_20.head()
# Out:
#    Unnamed: 0  ... index
# 0           0  ...   NaN
# 1           1  ...   NaN
# 2           2  ...   NaN
# 3           3  ...   NaN
# 4           4  ...   NaN
#
# [5 rows x 15 columns]

# %%
# '제안일자'기준 정렬 후 합치기

BillDf_20 = BillDf_20.sort_values(by="제안일자")
BillDf_21 = BillDf_21.sort_values(by="제안일자")

BillDf = pd.concat([BillDf_20,BillDf_21]).drop(['Unnamed: 0','index'],axis=1)
BillDf.head()
# Out:
#           의안번호 처리여부  ...    소관위원회                                                제안자
# 25221  2000001    처  ...  외교통일위원회  ['박정(더불어민주당/朴釘)', '김경협(더불어민주당/金炅俠)', '노웅래(더불어민...
# 25192  2000030    처  ...  환경노동위원회  ['이완영(새누리당/李完永)', '강석진(새누리당/姜錫振)', '강석호(새누리당/姜...
# 25191  2000031    처  ...  환경노동위원회  ['이완영(새누리당/李完永)', '강석진(새누리당/姜錫振)', '강석호(새누리당/姜...
# 25190  2000032    처  ...    정보위원회  ['이철우(새누리당/李喆雨)', '강석진(새누리당/姜錫振)', '강석호(새누리당/姜...
# 25189  2000033    처  ...    정무위원회  ['김광림(새누리당/金光琳)', '강석진(새누리당/姜錫振)', '권석창(새누리당/權...
#
# [5 rows x 13 columns]

# %%
BillDf.isna().sum()
# Out:
# 의안번호          0
# 처리여부          0
# 의안명           0
# 제안자구분         0
# 제안일자          0
# 의결일자       4351
# 의결결과       4351
# 심사진행상태    25222
# 문서          246
# 제안회기          0
# 제안이유        557
# 소관위원회       119
# 제안자        1631
# dtype: int64

# %% [markdown]
# ## 전처리

# %% [markdown]
# #### 함수

# %%
# 전처리 함수 생성

def preprocessing(BillDf):
    
    
    # 결측값 처리
    
    BillDf = BillDf.fillna("")


    
    # [의안번호] ZZ로 시작하는 행 삭제 
    
    startZ = BillDf[BillDf['의안번호'].str.startswith('ZZ')]

    BillDf.drop(startZ.index, inplace=True)
    BillDf = BillDf.reset_index(drop=True)
    
    
    
    
    # [제안이유] 특수문자 및 '제안이유 및 주요내용', '제안이유', '주요내용' 문자열 삭제
    
    def clean_reason(df_col): 
        text = df_col[2:-2].replace('제안이유 및 주요내용','').replace('대안의 제안이유 및 주요내용','').replace('대안의 주요내용','').replace('대안의 제안이유','').replace('제안이유','').replace('주요내용','')
        return re.sub('[-=.#/:$}·,■?]', ' ', text)
    
    BillDf['제안이유'] = BillDf['제안이유'].apply(lambda x: clean_reason(x))
    
    

    
    
    # [의안명]뒤 대표 제안자 포함 괄호 삭제
    
    for i in range(len(BillDf)):
        BillDf['의안명'][i] = BillDf['의안명'][i].split('(')[0]
        
        
        
        
    # [의안명]에 '법률안' 포함하는 경우만 남기고 삭제 (법률안 -> 4254개 중 4007개) 
    
    BillDf.loc[BillDf['의안명'].str.endswith('법률안') == True, '법률안'] = 1
    BillDf.loc[BillDf['의안명'].str.endswith('법률안') == False, '법률안'] = 0
    BillDf = BillDf[BillDf['법률안'] == 1]
        
        
        
        
    # [제안자구분] 의원, 의장, 위원장 데이터만 남기고 삭제
    
    proposer_type_list = ['의원', '위원장', '의장']
    
    
    BillDf_new = BillDf[BillDf['제안자구분'].isin(proposer_type_list)]
    BillDf = BillDf_new.reset_index(drop = True)
    
    
    
    
    # [제안자] 스플릿, 제안 정당만 따와서 리스트로 변환, 중복제거 -> [제안정당] 칼럼 생성
    
    BillDf['제안자'] = BillDf['제안자'].str.split(',')
    BillDf['제안자'] = BillDf['제안자'].fillna("a") #object of type 'float' has no len() 오류 해결

    list1 = []

    for i in range(len(BillDf)):

        list2 = []

        if BillDf['제안자'][i] != "a":

            for j in range(len(BillDf['제안자'][i])):

                list2.append(BillDf['제안자'][i][j].split('(')[-1].split('/')[0])

            list1.append(list(set(list2)))

        else:
            list1.append(np.NaN)

    BillDf['제안정당'] = list1  
    
    
    
    
    # [제안자구분] '위원장'인 경우 제안정당 -> 더불어민주당으로 채우기
    
    for i in range(len(BillDf)):
        if BillDf['제안자구분'][i]=='위원장':
            BillDf['제안정당'][i]=[]
            BillDf['제안정당'][i].append('더불어민주당')

            

            
    # [소관위원회] 없는 행 제거
    
    noncomm = BillDf[BillDf['소관위원회'] == ''].index
    BillDf.drop(noncomm,inplace=True)
    BillDf = BillDf.reset_index(drop=True)
    
    noncomm = BillDf[BillDf['소관위원회'] == '[]'].index
    BillDf.drop(noncomm,inplace=True)
    BillDf = BillDf.reset_index(drop=True)
    
    
    
    
    # [의결결과] 공포, 미공포 분류
    
    proclaim_list = ['원안가결', '수정가결']
    reject_list = ['임기만료폐기', '대안반영폐기', '철회', '폐기', '부결', '수정안반영폐기']

    BillDf.loc[BillDf['의결결과'].isin(proclaim_list), '법률공포여부'] = '공포'
    BillDf.loc[BillDf['의결결과'].isin(reject_list), '법률공포여부'] = '미공포'
    
    
    
    # ['의안명']+[제안이유] -> ['텍스트'] 만들기
    
    
    BillDf['텍스트'] = ''
    
    for i in range(len(BillDf)):
        
        text = []
        
        text.append(BillDf['의안명'][i])
        text.append(BillDf['제안이유'][i])
    
        BillDf['텍스트'][i] = text
    
    
    
    # 결측값 처리
    
    BillDf = BillDf.fillna("")
    
    
    
    
    return BillDf

# %%
BillDf = preprocessing(BillDf)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
BillDf.head()
# Out:
#       의안번호 처리여부  ... 법률공포여부                                                텍스트
# 0  2000030    처  ...    미공포  [  산업재해보상보험법 일부개정법률안,   현행법은 사업주가 제공한 교통수단이나 그...
# 1  2000031    처  ...    미공포  [  파견근로자보호 등에 관한 법률 일부개정법률안,   동 법률이 제정된 이후 파견...
# 2  2000032    처  ...    미공포  [  국가 사이버안보에 관한 법률안, 2009년 7 7디도스 사건 이후 지속적인 사...
# 3  2000033    처  ...    미공포  [  행정규제기본법 폐지법률안,   저출산？고령화 시대 및 저성장에 대응하고 국가경...
# 4  2000034    처  ...    미공포  [  청년고용촉진 특별법 일부개정법률안, 2015년 12월말 15～29세 청년 실업...
#
# [5 rows x 17 columns]

# %%
BillDf.isna().sum()
# Out:
# 의안번호      0
# 처리여부      0
# 의안명       0
# 제안자구분     0
# 제안일자      0
# 의결일자      0
# 의결결과      0
# 심사진행상태    0
# 문서        0
# 제안회기      0
# 제안이유      0
# 소관위원회     0
# 제안자       0
# 법률안       0
# 제안정당      0
# 법률공포여부    0
# 텍스트       0
# dtype: int64

# %%
BillDf_ = BillDf.copy()

# %% [markdown]
# #### '환경'키워드를 포함하는 의안 가져오기

# %%
contain_env = []

for i in tqdm(range(len(BillDf_)), desc = "환경키워드"):
    if "환경" in str(BillDf_['텍스트'][i]):
        contain_env.append(True)
    else:
        contain_env.append(False)
        
Env = BillDf_[contain_env]
Env['텍스트'][:2]
# Out:
# 환경키워드: 100%|██████████| 26069/26069 [00:00<00:00, 34779.08it/s]
# 12    [  해양환경관리법 일부개정법률안, 최근 국제해사기구(IMO)의 온실가스 유해물질 ...
# 13    [  공직선거법 일부개정법률안, 현행법은 19세 이상의 국민에게 대통령선거ㆍ국회의원...
# Name: 텍스트, dtype: object

# %%
Env = Env.reset_index(drop=True)

# %%
len(Env)
# Out:
# 2956

# %% [markdown]
# #### 한글 제외 문자 제거

# %%
def onlyKorean(textlist):
    
    for i in tqdm(range(len(textlist)), desc = "텍스트전처리"):
        
        textlist[i] = re.sub('[^가-힣\s]','',str(textlist[i]))
    
    return textlist

Env['텍스트'] = onlyKorean(Env['텍스트'])
# Out:
# 텍스트전처리:   0%|          | 0/2956 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 텍스트전처리: 100%|██████████| 2956/2956 [00:00<00:00, 6601.67it/s]

# %% [markdown]
# ## 2. 형태소 분석기 결정

# %%
def hannanumtest(textlist):

        hannanum = Hannanum()
        nounlist = []
        
        for i in range(len(textlist)):
            n = re.sub('[-=.#/:$}·,■?]','', str(textlist[i]))
            k = re.sub('[0-9]','',n)
            nounlist.append(hannanum.nouns(k))


        return nounlist


def kkmatest(textlist):

        kkma = Kkma()
        nounlist = []
        
        for i in range(len(textlist)):
            n = re.sub('[-=.#/:$}·,■?]','',str(textlist[i]))
            k = re.sub('[0-9]','',n)
            nounlist.append(kkma.nouns(k))


        return nounlist


    
def okttest(textlist):

        okt = Okt()
        nounlist = []
        
        for i in range(len(textlist)):
            n = re.sub('[-=.#/:$}·,■?]','',str(textlist[i]))
            k = re.sub('[0-9]','',n)
            nounlist.append(okt.nouns(k))


        return nounlist

    
    
def komorantest(textlist):

        komoran = Komoran()
        nounlist = []
        
        for i in range(len(textlist)):
            n = re.sub('[-=.#/:$}·,■?]','',str(textlist[i]))
            k = re.sub('[0-9]','',n)
            nounlist.append(komoran.nouns(k))


        return nounlist

# %%
hannanum_result = hannanumtest(Env['텍스트'][:3])
kkma_result = kkmatest(Env['텍스트'][:3])
okt_result = okttest(Env['텍스트'][:3])
komoran_result = komorantest(Env['텍스트'][:3])

print('hannanum\n',hannanum_result[:3])
print('\nkkma\n',kkma_result[:3])
print('\nokt\n',okt_result[:3])
print('\nkomoran\n',komoran_result[:3])
# Out:
# hannanum
#  [['해양환경관리법', '일부개정법률안', '국제해사기구', '온실가스', '유해물질', '평형수', '등', '환경', '관련', '규제', '순차적', '시행', '시작', '비용', '경쟁', '리', '환경기준', '충족', '기존', '선박들', '친환경', '선박', '대체', '상황', '이', '친환경', '선박', '관련', '기술', '조선산업', '블루', '오션', '급부상하', '글로벌', '해운업계', '선두주자들', '초대형', '친환경', '선박', '투자', '수주', '가뭄', '국내', '조선업계', '이', '위기상황', '돌파구', '활용', '여지', '이', '정부', '친환경', '선박', '기술개발', '보급촉진', '적극', '수', '해양환경개선부담금', '용도사업', '중', '하나', '친환경', '선박', '기술개발', '이용', '보급', '필요', '사업', '추가', '것', '제조'], ['공직선거법', '일부개정법률안', '현행법', '세', '이상', '국민', '대통령선거국회의원선거지방의회의원선거', '지방자치단체장', '선거', '선거권', '부', '정치사회', '민주화', '교육수준', '향상', '인터넷', '등', '대중매체', '정보교류', '사회환경', '등', '세', '도달', '청소년', '독자적', '신념', '정치적', '판단', '기초', '선거권', '행사', '수', '능력', '소양', '수', '세계', '각국', '세', '세', '규정', '선거연령', '세', '추세', '미국', '독', '영국', '프랑스', '등', '세계', '개국', '선거연령', '세', '이', '오늘날', '발전', '사회', '세계적', '추세', '선거권', '연령', '세', '이상', '하향', '조정', '것', '조제항', '항', '제조제항제호'], ['환경친화적', '자동차', '개발', '보급', '촉진', '법률', '일부개정법률안', '현행법', '환경친화적', '자동차', '개발', '보급', '촉진', '해당', '자동차', '종합적', '계획', '시책', '수립', '추진', '자동차산업', '지속적', '발전', '국민', '생활환경', '향상', '도모', '국가경제', '이바지하', '것', '법', '목적', '이', '현행법', '전기자동차', '태양광자동차', '하이브리드자동차', '연료전지자동차', '천연가스자동차', '클린디젤자동차', '환경친화적', '자동차', '규정하', '해당', '자동차', '개발', '보급', '촉진', '폭스바겐', '배출가스', '조작사건', '계기', '클린디젤', '허상', '실상', '디젤자동차', '배기가스', '대기오염', '국민건강', '중대한', '위험', '야기', '사회문제', '대두', '유럽', '등', '선진', '국가', '클린디젤', '자동차사', '마케팅', '허상', '이', '디젤차', '규제', '퇴출', '세계적', '확산', '상황', '클린디젤자동차', '환경친화적', '자동차', '포함', '당시', '클린디젤자동차', '경우', '기술개발', '계속', '배출', '질소산화물', '여타', '환경친화적', '자동차', '수준', '감소', '데', '한계', '사실', '전문위원', '검토
것', '법', '목적', '현행법', '전기자동차', '태양광', '자동차', '하이브리드', '자동차', '연료전지', '자동차', '천연가스', '자동차', '클린', '디젤', '자동차', '환경', '친화', '자동차', '규정', '해당', '자동차', '개발', '보급', '촉진', '폭스바겐', '배출', '가스', '조작', '사건', '계기', '클린', '디젤', '허상', '실상', '디젤', '자동차', '배기가스', '대기', '오염', '국민', '건강', '위험', '야기', '사회', '문제', '대두', '유럽', '등', '선진', '국가', '클린', '디젤', '자동차사', '마케팅', '허상', '디젤', '차', '규제', '퇴출', '움직임', '세계', '확산', '상황', '클린', '디젤', '자동차', '환경', '친화', '자동차', '포함', '당시', '클린', '디젤', '자동차', '경우', '기술', '개발', '계속', '배출', '질소', '산화물', '여타', '환경', '친화', '자동차', '수준', '감소', '데', '한계', '사실', '고려', '전문', '위원', '검토', '보고서', '년', '월', '지적', '실', '주행', '기준', '초과', '것', '국제', '보건', '기구', '산하', '국제', '암', '연구소', '년', '디젤', '배기가스', '석면', '비소', '등급', '급', '발암', '물질', '규정', '대책', '마련', '촉구', '바', '클린', '디젤', '자동차', '환경', '친화', '자동차', '범주', '제외', '국민', '디젤', '자동차', '인식', '한편', '가스', '자동차', '범위', '공해', '자동차', '지정', '액화석유가스', '자동차', '포함', '기술', '개발', '보급', '촉진', '수송', '부분', '대기', '오염', '물질', '배출', '최소', '국민', '건강', '생활환경', '향상', '도모', '국가', '경쟁력', '향상', '기여', '것', '임', '안', '제조']]

# %% [markdown]
# **=> Hannanum을 사용하자!**

# %% [markdown]
# ## 3. 토큰화

# %% [markdown]
# #### 함수

# %%
# 토큰생성

def get_tokens(text):
    
    hannanum = Hannanum()
        
    return [i for i in hannanum.nouns(text) if len(i) > 1] if text else []

# %% [markdown]
# #### 토큰화 및 토큰 개수 count

# %%
Env['토큰'] = Env['텍스트'].map(get_tokens)

# %%
Env['명사수'] = Env['토큰'].map(len)

# %%
Env.head()
# Out:
#       의안번호 처리여부  ...                                                 토큰  명사수
# 0  2000042    처  ...  [해양환경관리법, 일부개정법률안, 국제해사기구, 온실가스, 유해물질, 평형수, 환경...   63
# 1  2000043    처  ...  [공직선거법, 일부개정법률안, 현행법, 이상, 국민, 대통령선거국회의원선거지방의회의...   51
# 2  2000010    처  ...  [환경친화적, 자동차, 개발, 보급, 촉진, 법률, 일부개정법률안, 현행법, 환경친...  139
# 3  2000019    처  ...  [국가재정법, 일부개정법률안, 경상북, 울릉도독도, 지역, 동해, 유일, 접경지역,...  106
# 4  2000062    처  ...  [유통산업발전법, 일부개정법률안, 현행법, 대기업, 지역상권, 진출로, 전통시장, ...   64
#
# [5 rows x 19 columns]

# %%
Env['명사수'].describe()
# Out:
# count    2956.000000
# mean      104.891069
# std       100.904634
# min        14.000000
# 25%        60.000000
# 50%        77.000000
# 75%       116.000000
# max      2327.000000
# Name: 명사수, dtype: float64

# %%
len(Env)
# Out:
# 2956

# %%
# csv로 저장
Env.to_csv('environment_tocken.csv', encoding='utf-8-sig')
